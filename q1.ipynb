# %%
# Exercici 0
# Pau Blasco Roca 1600959

# %%
var('x y')
# Out:
# (x, y)

# %%
eq11=x
eq12=y
plot=plot_vector_field((eq11,eq12), (x,-2,2), (y,-2,2));#al voltant de 0,0
show(plot)
#Veiem que es tracta d'un node estrella repulsor, ja que els vectors
#del retrat apunten cap a fora en forma d'estrella
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
A01=matrix(SR,[[diff(eq11,x),diff(eq11,y)],[diff(eq12,x),diff(eq12,y)]]);
show(A01)
# Out:
# [1 0]
# [0 1]

# %%
A01.eigenvalues()
#Els vaps son positius, confirmem que es tracta d'un node repulsor
# Out:
# [1, 1]

# %%
eq21=x+y
eq22=y
plot=plot_vector_field((eq21,eq22),(x,-2,2),(y,-2,2)); 
show(plot)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
A02=matrix(SR,[[diff(eq21,x),diff(eq21,y)],[diff(eq22,x),diff(eq22,y)]]);
show(A02)
# Out:
# [1 1]
# [0 1]

# %%
A02.eigenvalues()
#Els vaps son positius, confirmem que es tracta d'un node repulsor
# Out:
# [1, 1]

# %%
eq31=-0.5*x
eq32=-y
plot=plot_vector_field((eq31,eq32), (x,-2,2), (y,-2,2));
show(plot)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
A03=matrix(SR,[[diff(eq31,x),diff(eq31,y)],[diff(eq32,x),diff(eq32,y)]]);
show(A03)
# Out:
# [-0.500000000000000                  0]
# [                 0                 -1]

# %%
A03.eigenvalues()
#Els vaps son negatius, aleshores es tracta d'un node atractor
#Les condicions necessàries per a que el node sigui atractor
#és que la part real dels dos vaps sigui negativa.
# Out:
# [-1/2, -1]
