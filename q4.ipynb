# %%
# Exercici 3
# Pau Blasco Roca 1600959

# %%
var('x y')
# Out:
# (x, y)

# %%
eq1=x^2+2*y^2
eq2=y+y^2
res=solve([eq1,eq2],x,y);
show(res) #només ens quedem amb la primera, que pertany a R^2
# Out:
# [[x == 0, y == 0], [x == -I*sqrt(2), y == -1], [x == I*sqrt(2), y == -1]]

# %%
plot=plot_vector_field((eq1,eq2), (x,0-0.2,0+0.2), (y,0-0.2,0+0.2));
show(plot)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
A3=matrix([[diff(eq1,x),diff(eq1,y)],[diff(eq2,x),diff(eq2,y)]]).subs(x=0,y=0);
show(A3)
A3.eigenvalues()
#Com que un eigenvalue és zero, no podem determinar quin tipus de node és amb la teoria
#No obstant, amb el retrat de fase observem que es tracta d'una sella
# Out:
# [0 0]
# [0 1]
# [0, 1]
